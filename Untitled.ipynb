# %%
# !pip install scipy==1.10.1 gensim==4.3.1 numpy==1.23.5 --force-reinstall
# Out:
# Collecting scipy==1.10.1
#   Downloading scipy-1.10.1-cp310-cp310-macosx_12_0_arm64.whl (28.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 17.8 MB/s eta 0:00:0000:0100:01
# Collecting gensim==4.3.1
#   Downloading gensim-4.3.1-cp310-cp310-macosx_11_0_arm64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 3.4 MB/s eta 0:00:0000:0100:01
# Collecting numpy==1.23.5
#   Downloading numpy-1.23.5-cp310-cp310-macosx_11_0_arm64.whl (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 17.8 MB/s eta 0:00:0000:0100:01
# Collecting smart-open>=1.8.1
#   Downloading smart_open-7.5.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 8.5 MB/s eta 0:00:00
# Collecting wrapt
#   Downloading wrapt-2.0.1-cp310-cp310-macosx_11_0_arm64.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: wrapt, numpy, smart-open, scipy, gensim
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 7.1.0
#     Uninstalling smart-open-7.1.0:
#       Successfully uninstalled smart-open-7.1.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.3
#     Uninstalling gensim-4.3.3:
#       Successfully uninstalled gensim-4.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.23.5 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 1.23.5 which is incompatible.
# pmdarima 2.1.1 requires scipy>=1.13.0, but you have scipy 1.10.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.23.5 which is incompatible.
# langchain-community 0.3.27 requires numpy>=1.26.2; python_version < "3.13", but you have numpy 1.23.5 which is incompatible.
# faiss-cpu 1.11.0 requires numpy<3.0,>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# Successfully installed gensim-4.3.1 numpy-1.23.5 scipy-1.10.1 smart-open-7.5.0 wrapt-2.0.1
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip uninstall -y transformers sentence-transformers
# Out:
# Found existing installation: transformers 4.52.4
# Uninstalling transformers-4.52.4:
#   Successfully uninstalled transformers-4.52.4
# Found existing installation: sentence-transformers 4.1.0
# Uninstalling sentence-transformers-4.1.0:
#   Successfully uninstalled sentence-transformers-4.1.0

# %%
# !pip install transformers==4.30.2 sentence-transformers
# Out:
# Collecting transformers==4.30.2
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 24.7 MB/s eta 0:00:0000:0100:01
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.2.0-py3-none-any.whl (493 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 19.2 MB/s eta 0:00:00
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-macosx_12_0_arm64.whl (3.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 10.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.30.2) (0.32.4)
# Requirement already satisfied: pyyaml>=5.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.30.2) (6.0.2)
# Requirement already satisfied: filelock in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.30.2) (3.18.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.30.2) (25.0)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.30.2) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.30.2) (4.67.1)
# Requirement already satisfied: numpy>=1.17 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.30.2) (1.23.5)
# Requirement already satisfied: requests in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.30.2) (2.32.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers==4.30.2) (2024.11.6)
# Requirement already satisfied: scikit-learn in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (1.7.0)
# Requirement already satisfied: scipy in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (2.9.1)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.0/488.0 kB 10.2 MB/s eta 0:00:00a 0:00:01
#   Downloading sentence_transformers-5.1.1-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.6/486.6 kB 11.1 MB/s eta 0:00:0000:01
#   Downloading sentence_transformers-5.1.0-py3-none-any.whl (483 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.4/483.4 kB 10.6 MB/s eta 0:00:00a 0:00:01
#   Using cached sentence_transformers-5.0.0-py3-none-any.whl (470 kB)
#   Using cached sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
#   Downloading sentence_transformers-4.0.2-py3-none-any.whl (340 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.6/340.6 kB 8.6 MB/s eta 0:00:0000:01
#   Downloading sentence_transformers-4.0.1-py3-none-any.whl (340 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.6/340.6 kB 8.4 MB/s eta 0:00:0000:01
#   Downloading sentence_transformers-4.0.0-py3-none-any.whl (336 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.0/337.0 kB 7.1 MB/s eta 0:00:00a 0:00:01
#   Downloading sentence_transformers-3.4.1-py3-none-any.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.9/275.9 kB 8.9 MB/s eta 0:00:00
#   Downloading sentence_transformers-3.4.0-py3-none-any.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 8.4 MB/s eta 0:00:00
#   Downloading sentence_transformers-3.3.1-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 11.4 MB/s eta 0:00:00
#   Downloading sentence_transformers-3.3.0-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.7/268.7 kB 10.2 MB/s eta 0:00:00
#   Downloading sentence_transformers-3.2.1-py3-none-any.whl (255 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.8/255.8 kB 9.7 MB/s eta 0:00:00
#   Downloading sentence_transformers-3.2.0-py3-none-any.whl (255 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.2/255.2 kB 10.6 MB/s eta 0:00:00
#   Downloading sentence_transformers-3.1.1-py3-none-any.whl (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 12.0 MB/s eta 0:00:00
#   Downloading sentence_transformers-3.1.0-py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.1/249.1 kB 10.0 MB/s eta 0:00:00
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 10.8 MB/s eta 0:00:00
#   Downloading sentence_transformers-3.0.0-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.7/224.7 kB 12.0 MB/s eta 0:00:00
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 9.9 MB/s eta 0:00:00
#   Downloading sentence_transformers-2.6.1-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 8.6 MB/s eta 0:00:00
#   Downloading sentence_transformers-2.6.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.1/163.1 kB 10.5 MB/s eta 0:00:00
#   Downloading sentence_transformers-2.5.1-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 8.6 MB/s eta 0:00:00
#   Downloading sentence_transformers-2.5.0-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 8.0 MB/s eta 0:00:00
#   Downloading sentence_transformers-2.4.0-py3-none-any.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.5/149.5 kB 7.1 MB/s eta 0:00:00
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 5.9 MB/s eta 0:00:00
#   Downloading sentence_transformers-2.3.0-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 6.1 MB/s eta 0:00:00
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torchvision in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (0.24.1)
# Requirement already satisfied: nltk in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (3.9.1)
# Requirement already satisfied: sentencepiece in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence-transformers) (0.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (1.1.3)
# Requirement already satisfied: networkx>=2.5.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: click in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nltk->sentence-transformers) (8.2.1)
# Requirement already satisfied: joblib in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nltk->sentence-transformers) (1.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests->transformers==4.30.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests->transformers==4.30.2) (2025.7.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests->transformers==4.30.2) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests->transformers==4.30.2) (2.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torchvision->sentence-transformers) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=d92732160c16e131c2e357141f841333e07f8d500f232b90f1499c393ee2b8be
#   Stored in directory: /Users/dhrubieee/Library/Caches/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, transformers, sentence-transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
# Successfully installed sentence-transformers-2.2.2 tokenizers-0.13.3 transformers-4.30.2
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (0.18.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip uninstall -y numpy scipy
# !pip install numpy==1.26.4
# !pip install scipy
# Out:
# Found existing installation: numpy 1.23.5
# Uninstalling numpy-1.23.5:
#   Successfully uninstalled numpy-1.23.5
# Found existing installation: scipy 1.10.1
# Uninstalling scipy-1.10.1:
#   Successfully uninstalled scipy-1.10.1
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xgboost 3.1.2 requires scipy, which is not installed.
# ultralytics 8.3.235 requires scipy>=1.4.1, which is not installed.
# statsmodels 0.14.6 requires scipy!=1.9.2,>=1.8, which is not installed.
# sentence-transformers 2.2.2 requires scipy, which is not installed.
# scikit-learn 1.7.0 requires scipy>=1.8.0, which is not installed.
# pmdarima 2.1.1 requires scipy>=1.13.0, which is not installed.
# gensim 4.3.1 requires scipy>=1.7.0, which is not installed.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Collecting scipy
#   Using cached scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl (22.4 MB)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from scipy) (1.26.4)
# Installing collected packages: scipy
# Successfully installed scipy-1.15.3
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip uninstall nltk -y
# !pip install nltk
# Out:
# Found existing installation: nltk 3.9.1
# Uninstalling nltk-3.9.1:
#   Successfully uninstalled nltk-3.9.1
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: joblib in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nltk) (1.5.1)
# Requirement already satisfied: tqdm in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: click in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from nltk) (8.2.1)
# Installing collected packages: nltk
# Successfully installed nltk-3.9.2
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (0.32.4)
# Collecting huggingface_hub
#   Downloading huggingface_hub-1.2.3-py3-none-any.whl (520 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.0/521.0 kB 3.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyyaml>=5.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: filelock in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (3.18.0)
# Collecting typer-slim
#   Downloading typer_slim-0.21.0-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: shellingham in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (1.5.4)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (4.14.1)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: packaging>=20.9 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (25.0)
# Collecting hf-xet<2.0.0,>=1.2.0
#   Downloading hf_xet-1.2.0-cp37-abi3-macosx_11_0_arm64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 2.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (2025.5.1)
# Requirement already satisfied: idna in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.10)
# Requirement already satisfied: certifi in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: anyio in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.9.0)
# Requirement already satisfied: h11>=0.16 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: click>=8.0.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from typer-slim->huggingface_hub) (8.2.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub) (1.3.0)
# Installing collected packages: typer-slim, hf-xet, huggingface_hub
#   Attempting uninstall: hf-xet
#     Found existing installation: hf-xet 1.1.3
#     Uninstalling hf-xet-1.1.3:
#       Successfully uninstalled hf-xet-1.1.3
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.32.4
#     Uninstalling huggingface-hub-0.32.4:
#       Successfully uninstalled huggingface-hub-0.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.30.2 requires huggingface-hub<1.0,>=0.14.1, but you have huggingface-hub 1.2.3 which is incompatible.
# Successfully installed hf-xet-1.2.0 huggingface_hub-1.2.3 typer-slim-0.21.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade sentence_transformers huggingface_hub transformers
# Out:
# Requirement already satisfied: sentence_transformers in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (2.2.2)
# Collecting sentence_transformers
#   Using cached sentence_transformers-5.2.0-py3-none-any.whl (493 kB)
# Requirement already satisfied: huggingface_hub in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (1.2.3)
# Requirement already satisfied: transformers in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (4.30.2)
# Collecting transformers
#   Downloading transformers-4.57.3-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 7.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tqdm in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence_transformers) (4.14.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence_transformers) (2.9.1)
# Requirement already satisfied: scikit-learn in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence_transformers) (1.7.0)
# Requirement already satisfied: scipy in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sentence_transformers) (1.15.3)
# Requirement already satisfied: pyyaml>=5.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: typer-slim in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (0.21.0)
# Requirement already satisfied: shellingham in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (1.5.4)
# Requirement already satisfied: packaging>=20.9 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (2025.5.1)
# Requirement already satisfied: filelock in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from huggingface_hub) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: numpy>=1.17 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (1.26.4)
# Collecting tokenizers<=0.23.0,>=0.22.0
#   Downloading tokenizers-0.22.1-cp39-abi3-macosx_11_0_arm64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 17.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: safetensors>=0.4.3 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (0.5.3)
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: anyio in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.10)
# Requirement already satisfied: certifi in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2025.7.14)
# Requirement already satisfied: h11>=0.16 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: jinja2 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: sympy>=1.13.3 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Requirement already satisfied: click>=8.0.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from typer-slim->huggingface_hub) (8.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Installing collected packages: huggingface_hub, tokenizers, transformers, sentence_transformers
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.2.3
#     Uninstalling huggingface_hub-1.2.3:
#       Successfully uninstalled huggingface_hub-1.2.3
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.3
#     Uninstalling tokenizers-0.13.3:
#       Successfully uninstalled tokenizers-0.13.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.30.2
#     Uninstalling transformers-4.30.2:
#       Successfully uninstalled transformers-4.30.2
#   Attempting uninstall: sentence_transformers
#     Found existing installation: sentence-transformers 2.2.2
#     Uninstalling sentence-transformers-2.2.2:
#       Successfully uninstalled sentence-transformers-2.2.2
# Successfully installed huggingface_hub-0.36.0 sentence_transformers-5.2.0 tokenizers-0.22.1 transformers-4.57.3
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (1.11.0)
# Requirement already satisfied: packaging in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/dhrubieee/.pyenv/versions/3.10.13/lib/python3.10/site-packages (from faiss-cpu) (1.26.4)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
pip install openai==0.28
# Out:
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.20 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai==0.28) (2.32.3)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from openai==0.28) (4.67.1)
# Collecting aiohttp (from openai==0.28)
#   Downloading aiohttp-3.13.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.20->openai==0.28) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.20->openai==0.28) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.20->openai==0.28) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.20->openai==0.28) (2025.1.31)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->openai==0.28)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->openai==0.28)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from aiohttp->openai==0.28) (25.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->openai==0.28)
#   Downloading frozenlist-1.8.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->openai==0.28)
#   Downloading multidict-6.7.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->openai==0.28)
#   Downloading propcache-0.4.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->openai==0.28)
#   Downloading yarl-1.22.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (75 kB)
# Downloading openai-0.28.0-py3-none-any.whl (76 kB)
# Downloading aiohttp-3.13.2-cp313-cp313-macosx_11_0_arm64.whl (489 kB)
# Downloading multidict-6.7.0-cp313-cp313-macosx_11_0_arm64.whl (43 kB)
# Downloading yarl-1.22.0-cp313-cp313-macosx_11_0_arm64.whl (93 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-macosx_11_0_arm64.whl (49 kB)
# Downloading propcache-0.4.1-cp313-cp313-macosx_11_0_arm64.whl (46 kB)
# Installing collected packages: propcache, multidict, frozenlist, aiohappyeyeballs, yarl, aiosignal, aiohttp, openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [openai]2m7/8 [openai]
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 frozenlist-1.8.0 multidict-6.7.0 openai-0.28.0 propcache-0.4.1 yarl-1.22.0
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: /Library/Frameworks/Python.framework/Versions/3.13/bin/python3.13 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from textblob import TextBlob
from wordcloud import WordCloud
from gensim import corpora, models
from fuzzywuzzy import fuzz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       8 from textblob import TextBlob
#       9 from wordcloud import WordCloud
# ---> 10 from gensim import corpora, models
#      11 from fuzzywuzzy import fuzz
#
# ModuleNotFoundError: No module named 'gensim'
