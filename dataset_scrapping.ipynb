# %% [markdown]
# # Install Requirements

# %%
# !pip install kaggle selenium webdriver_manager
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.5)
# Collecting selenium
#   Downloading selenium-4.33.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting webdriver_manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)
# Collecting trio~=0.30.0 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting typing_extensions~=4.13.2 (from selenium)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Collecting python-dotenv (from webdriver_manager)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from webdriver_manager) (24.2)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (2.4.0)
# Collecting outcome (from trio~=0.30.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.33.0-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 67.4 MB/s eta 0:00:00
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 34.4 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, typing_extensions, python-dotenv, outcome, webdriver_manager, trio, trio-websocket, selenium
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.14.0
#     Uninstalling typing_extensions-4.14.0:
#       Successfully uninstalled typing_extensions-4.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# Successfully installed outcome-1.3.0.post0 python-dotenv-1.1.0 selenium-4.33.0 trio-0.30.0 trio-websocket-0.12.2 typing_extensions-4.13.2 webdriver_manager-4.0.2 wsproto-1.2.0

# %% [markdown]
# # Kaggle API set and fetch datasets

# %%
# Step 1: Create the correct folder
# !mkdir -p /root/.config/kaggle

# Step 2: Move kaggle.json to that location
# !mv kaggle.json /root/.config/kaggle/

# Step 3: Set correct permissions
# !chmod 600 /root/.config/kaggle/kaggle.json

# %%
import time
from kaggle.api.kaggle_api_extended import KaggleApi

api = KaggleApi()
api.authenticate()

N = 100  # desired number of datasets
all_datasets = []
page = 1

while len(all_datasets) < N:
    try:
        datasets = api.dataset_list(page=page)
        if not datasets:
            break
        all_datasets.extend(datasets)
        print(f"Fetched page {page}, total datasets collected: {len(all_datasets)}")
        page += 1
        time.sleep(2)  # wait 2 seconds between requests to avoid rate limiting
    except Exception as e:
        print(f"Error fetching page {page}: {e}")
        break

all_datasets = all_datasets[:N]

print(f"\nTotal datasets fetched: {len(all_datasets)}\n")

for i, dataset in enumerate(all_datasets, start=1):
    dataset_url = f"https://www.kaggle.com/datasets/{dataset.ref}"
    print(f"{i}. {dataset.title} - {dataset_url}")
# Out:
# Fetched page 1, total datasets collected: 20
# Fetched page 2, total datasets collected: 40
# Fetched page 3, total datasets collected: 60
# Fetched page 4, total datasets collected: 80
# Fetched page 5, total datasets collected: 99
# Fetched page 6, total datasets collected: 117
#
# Total datasets fetched: 100
#
# 1. Extrovert vs. Introvert Behavior Data - https://www.kaggle.com/datasets/rakeshkapilavai/extrovert-vs-introvert-behavior-data
# 2. Students' Social Media Addiction - https://www.kaggle.com/datasets/adilshamim8/social-media-addiction-vs-relationships
# 3. Global AI Job Market & Salary Trends 2025 - https://www.kaggle.com/datasets/bismasajjad/global-ai-job-market-and-salary-trends-2025
# 4. 🌮 Taco Sales Dataset (2024–2025) - https://www.kaggle.com/datasets/atharvasoundankar/taco-sales-dataset-20242025
# 5. Video Game Sales - https://www.kaggle.com/datasets/siddharth0935/video-game-sales
# 6. Student Habits vs Academic Performance - https://www.kaggle.com/datasets/jayaantanaath/student-habits-vs-academic-performance
# 7. OpenFWI Preprocessed 72x72 - https://www.kaggle.com/datasets/brendanartley/openfwi-preprocessed-72x72
# 8. Zepto Inventory Dataset - https://www.kaggle.com/datasets/palvinder2006/zepto-inventory-dataset
# 9. Ben 10 Alien Universe —  Realistic Battle Dataset - https://www.kaggle.com/datasets/atharvasoundankar/ben-10-alien-universe-realistic-battle-dataset
# 10. Retail Store Inventory and Demand Forecasting - https://www.kaggle.com/datasets/atomicd/retail-store-inventory-and-demand-forecasting
# 11. COVID-19 Reinfection and Health Dataset - https://www.kaggle.com/datasets/khushikyad001/covid-19-reinfection-and-health-dataset
# 12. Global Air Quality (2024) - 6 Cities - https://www.kaggle.com/datasets/youssefelebiary/air-quality-2024
# 13. 🧠 AI Developer Productivity Dataset - https://www.kaggle.com/datasets/atharvasoundankar/ai-developer-productivity-dataset
# 14. 2020-2025 Google Stock Dataset - https://www.kaggle.com/datasets/samanfatima7/2020-2025-google-stock-dataset
# 15. Electric car sales (2010-2024) - https://www.kaggle.com/datasets/jainaru/electric-car-sales-2010-2024
# 16. Student Academic Performance Dataset - https://www.kaggle.com/datasets/therohithanand/student-academic-performance-dataset
# 17. Rock Paper Scissors SXSW: Hand Gesture Detection - https://www.kaggle.com/datasets/adilshamim8/rock-paper-scissors
# 18. Social Media vs Productivity - https://www.kaggle.com/datasets/mahdimashayekhi/social-media-vs-productivity
# 19. Melbourne Housing Snapshot - https://www.kaggle.com/datasets/dansbecker/melbourne-housing-snapshot
# 20. Stress and Sleep Patterns - https://www.kaggle.com/datasets/orvile/stress-and-sleep-patterns
# 21. Heart Attack Dataset - https://www.kaggle.com/datasets/fatemehmohammadinia/heart-attack-dataset-tarik-a-rashid
# 22. Global Internet Adoption & Digital Growth Analysis - https://www.kaggle.com/datasets/sudipde25/global-internet-adoption-trends
# 23. Health and Sleep relation  - https://www.kaggle.com/datasets/orvile/health-and-sleep-relation-2024
# 24. Trending YouTube Video Statistics - https://www.kaggle.com/datasets/datasnaek/youtube-new
# 25. Kaggle’s Most Upvoted Datasets Overview - https://www.kaggle.com/datasets/ritalin56/kaggles-most-upvoted-datasets-overview
# 26. Wine Reviews - https://www.kaggle.com/datasets/zynicide/wine-reviews
# 27. Chess Game Dataset (Lichess) - https://www.kaggle.com/datasets/datasnaek/chess
# 28. Ramen Ratings - https://www.kaggle.com/datasets/residentmario/ramen-ratings
# 29. powerlifting-database - https://www.kaggle.com/datasets/dansbecker/powerlifting-database
# 30. 1.88 Million US Wildfires - https://www.kaggle.com/datasets/rtatman/188-million-us-wildfires
# 31. Kepler Exoplanet Search Results - https://www.kaggle.com/datasets/nasa/kepler-exoplanet-search-results
# 32. US Public Food Assistance 1 - WIC - https://www.kaggle.com/datasets/jpmiller/publicassistance
# 33. Things on Reddit - https://www.kaggle.com/datasets/residentmario/things-on-reddit
# 34. 18,393 Pitchfork Reviews - https://www.kaggle.com/datasets/nolanbconaway/pitchfork-data
# 35. Top 100 SaaS Companies/Startups 2025 - https://www.kaggle.com/datasets/shreyasdasari7/top-100-saas-companiesstartups
# 36. Himalayan Expeditions - https://www.kaggle.com/datasets/siddharth0935/himalayan-expeditions
# 37. Student Mental Health Analysis - https://www.kaggle.com/datasets/utkarshsharma11r/student-mental-health-analysis
# 38. Mobile Price Classification - https://www.kaggle.com/datasets/iabhishekofficial/mobile-price-classification
# 39. Eye Cancer Patient Records - https://www.kaggle.com/datasets/ak0212/eye-cancer-patient-records
# 40. Doraemon Complete Data - https://www.kaggle.com/datasets/samasiayushman/doraemon-complete-data
# 41. Fitness Tracker Data - https://www.kaggle.com/datasets/narinder06/fitness-tracker-data
# 42. Educational Backgrounds of Successful People - https://www.kaggle.com/datasets/adilshamim8/educational-backgrounds-of-successful-people
# 43. Real Estate Sales 2001-2022 - https://www.kaggle.com/datasets/omniamahmoudsaeed/real-estate-sales-2001-2022
# 44. home data for ml course - https://www.kaggle.com/datasets/dansbecker/home-data-for-ml-course
# 45. Cost of International Education - https://www.kaggle.com/datasets/adilshamim8/cost-of-international-education
# 46. Cigarettes & Alcohol Addiction - https://www.kaggle.com/datasets/khushikyad001/cigarettes-and-alcohol-addiction
# 47. Student Habits and Academic Performance Dataset - https://www.kaggle.com/datasets/aryan208/student-habits-and-academic-performance-dataset
# 48. Avocado Ripeness Classification Dataset - https://www.kaggle.com/datasets/amldvvs/avocado-ripeness-classification-dataset
# 49. Global Street Food Dataset - https://www.kaggle.com/datasets/benjnb/global-street-food-dataset
# 50. TMDB Top Movies Dataset - https://www.kaggle.com/datasets/spypsc07/imdb-top-movies-dataset
# 51. China Cancer Patient Records - https://www.kaggle.com/datasets/ak0212/china-cancer-patient-records
# 52. Social Media Engagement Dataset - https://www.kaggle.com/datasets/subashmaster0411/social-media-engagement-dataset
# 53. Airline Loyalty Program (Canada) - https://www.kaggle.com/datasets/siddharth0935/airline-loyalty-program
# 54. NBA Player's Database - https://www.kaggle.com/datasets/yagizfiratt/nba-players-database
# 55. Eye Detection Dataset - https://www.kaggle.com/datasets/icebearogo/eye-detection-dataset
# 56. China Water Pollution Monitoring Dataset - https://www.kaggle.com/datasets/khushikyad001/china-water-pollution-monitoring-dataset
# 57. 2025 Premier League: Stats, Matches, Salaries - https://www.kaggle.com/datasets/flynn28/2025-premier-league-stats-matches-salaries
# 58. Airline Market Fare Prediction Data - https://www.kaggle.com/datasets/orvile/airline-market-fare-prediction-data
# 59. 🌍Work-from-Anywhere Salary Insight (2024) - https://www.kaggle.com/datasets/atharvasoundankar/work-from-anywhere-salary-insight-2024
# 60. Sales Dataset - https://www.kaggle.com/datasets/sahilislam007/sales-dataset
# 61. SA-ME Happiness Index - https://www.kaggle.com/datasets/towhid121/sa-me-happiness-index
# 62. Crop Recommendation Dataset - https://www.kaggle.com/datasets/madhuraatmarambhagat/crop-recommendation-dataset
# 63. Pavement Dataset - https://www.kaggle.com/datasets/gifreysulay/pavement-dataset
# 64. Enhanced Pizza Sales Data (2024–2025)  - https://www.kaggle.com/datasets/akshaygaikwad448/pizza-delivery-data-with-enhanced-features
# 65. Student Performance - https://www.kaggle.com/datasets/neuralsorcerer/student-performance
# 66. Popular Street Foods - https://www.kaggle.com/datasets/nikolasgegenava/popular-street-foods
# 67. Shinchan Complete Dataset - https://www.kaggle.com/datasets/samasiayushman/shinchan-complete-dataset
# 68. Bank Telemarketing - https://www.kaggle.com/datasets/younusmohamed/bank-telemarketing
# 69. Shopping Trends And Customer Behaviour Dataset - https://www.kaggle.com/datasets/sahilislam007/shopping-trends-and-customer-behaviour-dataset
# 70. World University Ranking - https://www.kaggle.com/datasets/aritra100/world-university-ranking
# 71. Sentiment Analysis Dataset - https://www.kaggle.com/datasets/abdelmalekeladjelet/sentiment-analysis-dataset
# 72. It's raining cats - https://www.kaggle.com/datasets/joannanplkrk/its-raining-cats
# 73. Credit Card Fraud Detection - https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# 74. Mental Health - https://www.kaggle.com/datasets/mahdimashayekhi/mental-health
# 75. Palmer Archipelago (Antarctica) penguin data  - https://www.kaggle.com/datasets/parulpandey/palmer-archipelago-antarctica-penguin-data
# 76. Financial Transactions Dataset for Fraud Detection - https://www.kaggle.com/datasets/aryan208/financial-transactions-dataset-for-fraud-detection
# 77. Netflix Movies and TV Shows - https://www.kaggle.com/datasets/shivamb/netflix-shows
# 78. global_cancer_patients_2015_2024 - https://www.kaggle.com/datasets/zahidmughal2343/global-cancer-patients-2015-2024
# 79. Water Quality at Sydney Beaches 2025 - https://www.kaggle.com/datasets/umerhaddii/water-quality-at-sydney-beaches-2025
# 80. Interesting Data to Visualize - https://www.kaggle.com/datasets/alexisbcook/data-for-datavis
# 81. Mental Health and Digital Behavior (2020–2024) - https://www.kaggle.com/datasets/atharvasoundankar/mental-health-and-digital-behavior-20202024
# 82. bird2025 | sed ckpt - https://www.kaggle.com/datasets/i2nfinit3y/bird2025-sed-ckpt
# 83. GOOGLE STOCK PRICES (2004 - TODAY) - https://www.kaggle.com/datasets/emrekaany/google-daily-stock-prices-2004-today
# 84. Death Rates By Suicide - https://www.kaggle.com/datasets/sahilislam007/death-rates-by-suicide
# 85. Fake News Detection Dataset - https://www.kaggle.com/datasets/mahdimashayekhi/fake-news-detection-dataset
# 86. English Premier League (EPL) Match Data 2000-2025 - https://www.kaggle.com/datasets/marcohuiii/english-premier-league-epl-match-data-2000-2025
# 87. DC Characters - https://www.kaggle.com/datasets/mohitbansal31s/dc-characters
# 88. Letterbox Movie Classification Dataset - https://www.kaggle.com/datasets/sahilislam007/letterbox-movie-classification-dataset
# 89. Real & Fake News - https://www.kaggle.com/datasets/razanaqvi14/real-and-fake-news
# 90. Fake News Dataset - https://www.kaggle.com/datasets/moutasmtamimi/fake-news-dataset
# 91. Machine Learning Job Postings in the US - https://www.kaggle.com/datasets/ivankmk/thousand-ml-jobs-in-usa
# 92. V2: NBA Player Database - https://www.kaggle.com/datasets/flynn28/v2-nba-player-database
# 93. Pima Indians Diabetes Database - https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database
# 94. Iris Species - https://www.kaggle.com/datasets/uciml/iris
# 95. Animal Crossing New Horizons Catalog - https://www.kaggle.com/datasets/jessicali9530/animal-crossing-new-horizons-nookplaza-dataset
# 96. Cafe Rewards Offers - https://www.kaggle.com/datasets/siddharth0935/cafe-rewards-offers
# 97. Musical Instruments - https://www.kaggle.com/datasets/nikolasgegenava/music-instruments
# 98. Pokedex Pokemon Data - https://www.kaggle.com/datasets/lmno3418/pokedex-pokemon-data
# 99. Retail Sales Data set of Alcohol and Liquor - https://www.kaggle.com/datasets/fatemehmohammadinia/retail-sales-data-set-of-alcohol-and-liquor
# 100. Popular Sneakers Classification - https://www.kaggle.com/datasets/nikolasgegenava/sneakers-classification

# %% [markdown]
# # Create Datasets of Kaggle

# %%
import time
from kaggle.api.kaggle_api_extended import KaggleApi
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import requests
import pandas as pd

# Initialize Kaggle API
api = KaggleApi()
api.authenticate()

# Fetch datasets from Kaggle API
datasets = []
N = 2400  # Desired number of datasets
print("Fetching datasets from Kaggle API...")
all_datasets = []
page = 1

while len(all_datasets) < N:
    try:
        dataset_list = api.dataset_list(page=page)
        if not dataset_list:
            print("No more datasets available.")
            break
        all_datasets.extend(dataset_list)
        print(f"Fetched page {page}, total datasets collected: {len(all_datasets)}")
        page += 1
        time.sleep(2)  # Wait 2 seconds to avoid rate limiting
    except Exception as e:
        print(f"Error fetching page {page}: {e}")
        break

all_datasets = all_datasets[:N]  # Ensure we have exactly N datasets

# Convert API datasets to the required format
for dataset in all_datasets:
    datasets.append({
        "dataset_name": str(dataset.title).replace(",", " "),
        "dataset_url": f"https://www.kaggle.com/datasets/{dataset.ref}"
    })

print(f"\nTotal datasets fetched: {len(datasets)}\n")
for i, dataset in enumerate(datasets, start=1):
    print(f"{i}. {dataset['dataset_name']} - {dataset['dataset_url']}")

# Set up Selenium for dynamic content
options = Options()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
driver = webdriver.Chrome(options=options)

# Initialize list to store metadata
metadata_list = []

try:
    for dataset in datasets:
        dataset_name = dataset["dataset_name"]
        url = dataset["dataset_url"]
        print(f"\nProcessing: {dataset_name} ({url})")

        # Step 1: Get Meta Description using requests
        try:
            response = requests.get(url)
            meta_description = "no"
            if response.status_code == 200:
                soup_requests = BeautifulSoup(response.text, "html.parser")
                meta_tag = soup_requests.find("meta", attrs={"name": "description"})
                meta_description = meta_tag.get("content").replace(",", " ") if meta_tag else "no"
        except Exception as e:
            print(f"Error fetching meta description: {e}")
            meta_description = "no"

        # Step 2: Scrape page with Selenium
        headers = "no"
        about_dataset = "no"

        try:
            # Load the page
            driver.get(url)
            time.sleep(12)

            # Scroll to the bottom to load lazy content
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(2)

            # Click "View more" if present
            try:
                view_more = driver.find_element(By.XPATH, "//button[contains(text(), 'View more')] | //a[contains(text(), 'View more')]")
                view_more.click()
                time.sleep(2)
            except:
                print("No 'View more' button found")

            # Parse page source
            soup = BeautifulSoup(driver.page_source, "html.parser")

            # Extract Headers
            header_elements = soup.find_all(["h1", "h2", "h3"])
            headers = " ".join([h.get_text(strip=True).replace(",", " ") for h in header_elements]) if header_elements else "no"
            print("Headers found:", headers[:100] + "..." if len(headers) > 100 else headers)

            # Target "about dataset" for all entries
            target_section = "about dataset"

            # Find About Dataset section
            about_dataset = ""
            about_section = None
            for header in soup.find_all(["h1", "h2", "h3", "div"]):
                header_text = header.get_text(strip=True).lower()
                if target_section in header_text and len(header_text) < 30:
                    about_section = header
                    break

            if about_section:
                print(f"{target_section.title()} section found with tag:", about_section.name)
                parent = about_section.find_parent("div")
                if parent:
                    paragraphs = parent.find_all("p")
                    about_dataset = " ".join([p.get_text(strip=True).replace(",", " ") for p in paragraphs if p.get_text(strip=True)])
                else:
                    for sibling in about_section.find_all_next():
                        if sibling.name in ["h1", "h2", "h3"]:
                            break
                        if sibling.name == "p":
                            about_dataset += sibling.get_text(strip=True).replace(",", " ") + " "
            about_dataset = about_dataset.strip() or "no"
            print(f"{target_section.title()}:", about_dataset[:100] + "..." if len(about_dataset) > 100 else about_dataset)

        except Exception as e:
            print(f"Error scraping {url}: {e}")

        # Store metadata
        metadata_list.append({
            "dataset_name": dataset_name,
            "dataset_url": url,
            "header": headers,
            "about_dataset": about_dataset
        })

        # Progress tracking after each dataset
        print(f"Progress: {len(metadata_list)} out of {len(datasets)} datasets processed")

finally:
    driver.quit()

# Create DataFrame and save to CSV
df = pd.DataFrame(metadata_list)
df.to_csv("kaggle_datasets_metadata.csv", index=False)
print("\nMetadata saved to kaggle_datasets_metadata.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Processing: ALERT - Linguistic Extremism in Religious Text (https://www.kaggle.com/datasets/orvile/alert-linguistic-extremism-in-religious-text)
# No 'View more' button found
# Headers found: ALERT - Linguistic Extremism in Religious Text ALERT - Linguistic Extremism in Religious Text About ...
# About Dataset section found with tag: div
# About Dataset: The widespread dissemination of religiously aggressive content on social media platforms poses signi...
# Progress: 1687 out of 2400 datasets processed
#
# Processing: Road Sign Detection (https://www.kaggle.com/datasets/andrewmvd/road-sign-detection)
# No 'View more' button found
# Headers found: Road Sign Detection Road Sign Detection About Dataset About this Dataset How to Cite this Dataset Bi...
# About Dataset section found with tag: div
# About Dataset: This dataset contains877images of4 distinct classesfor the objective ofroad sign detection.Bounding ...
# Progress: 1688 out of 2400 datasets processed
#
# Processing: Car price prediction(used cars) (https://www.kaggle.com/datasets/vijayaadithyanvg/car-price-predictionused-cars)
# No 'View more' button found
# Headers found: Car price prediction(used cars) Car price prediction(used cars) About Dataset Usability License Expe...
# About Dataset section found with tag: div
# About Dataset: The price of a car depends on a lot of factors like the goodwill of the brand of the car  features o...
# Progress: 1689 out of 2400 datasets processed
#
# Processing: Housing Dataset (https://www.kaggle.com/datasets/ashydv/housing-dataset)
# No 'View more' button found
# Headers found: Housing Dataset Housing Dataset About Dataset Usability License Expected update frequency Tags Housi...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1690 out of 2400 datasets processed
#
# Processing: Facebook Live sellers in Thailand  UCI ML Repo (https://www.kaggle.com/datasets/ashishg21/facebook-live-sellers-in-thailand-uci-ml-repo)
# No 'View more' button found
# Headers found: Facebook Live sellers in Thailand  UCI ML Repo Facebook Live sellers in Thailand  UCI ML Repo About ...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1691 out of 2400 datasets processed
#
# Processing: Gender Recognition by Voice (https://www.kaggle.com/datasets/primaryobjects/voicegender)
# No 'View more' button found
# Headers found: Gender Recognition by Voice Gender Recognition by Voice About Dataset Voice Gender The Dataset Accur...
# About Dataset section found with tag: div
# About Dataset: Gender Recognition by Voice and Speech Analysis This database was created to identify a voice as mal...
# Progress: 1692 out of 2400 datasets processed
#
# Processing: Hong Kong Restaurant Licenses (https://www.kaggle.com/datasets/migrantworkerdatahub/hong-kong-restaurant-licenses)
# No 'View more' button found
# Headers found: Hong Kong Restaurant Licenses Hong Kong Restaurant Licenses About Dataset Usability License Expected...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1693 out of 2400 datasets processed
#
# Processing: Resume Dataset (https://www.kaggle.com/datasets/saugataroyarghya/resume-dataset)
# No 'View more' button found
# Headers found: Resume Dataset Resume Dataset About Dataset Usability License Expected update frequency Tags resume_...
# About Dataset section found with tag: div
# About Dataset: This dataset  curated and processed byNeuralframe AI  serves as a comprehensive resource for resume ...
# Progress: 1694 out of 2400 datasets processed
#
# Processing: Covid-19 Clinical Trials data (https://www.kaggle.com/datasets/nailasrivastava/covid-19-clinical-trials-data)
# No 'View more' button found
# Headers found: Covid-19 Clinical Trials data Covid-19 Clinical Trials data About Dataset Usability License Expected...
# About Dataset section found with tag: div
# About Dataset: This dataset contains detailed information about Covid-19-related clinical trials registered on Clin...
# Progress: 1695 out of 2400 datasets processed
#
# Processing: openvino_py_311 (https://www.kaggle.com/datasets/quan0095/openvino-py-311)
# No 'View more' button found
# Headers found: openvino_py_311 openvino_py_311 About Dataset Usability License Expected update frequency Tags openv...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1696 out of 2400 datasets processed
#
# Processing: configs_IMC2024 (https://www.kaggle.com/datasets/ammarali32/configs-imc2024)
# No 'View more' button found
# Headers found: configs_IMC2024 configs_IMC2024 About Dataset Usability License Expected update frequency Tags pipel...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1697 out of 2400 datasets processed
#
# Processing: AI vs. Human-Generated Images (https://www.kaggle.com/datasets/alessandrasala79/ai-vs-human-generated-dataset)
# No 'View more' button found
# Headers found: AI vs. Human-Generated Images AI vs. Human-Generated Images About Dataset Usability License Expected...
# About Dataset section found with tag: div
# About Dataset: Official dataset for the 2025 Women in AI Kaggle Competition:https://www.kaggle.com/competitions/det...
# Progress: 1698 out of 2400 datasets processed
#
# Processing: Hotel bookings (https://www.kaggle.com/datasets/mathsian/hotel-bookings)
# No 'View more' button found
# Headers found: Hotel bookings Hotel bookings About Dataset Source Description Usability License Expected update fre...
# About Dataset section found with tag: div
# About Dataset: https://www.researchgate.net/publication/329286343_Hotel_booking_demand_datasets These data sets con...
# Progress: 1699 out of 2400 datasets processed
#
# Processing: World-Cities  Pop  Lang  Rank (SQL create tbls) (https://www.kaggle.com/datasets/busielmorley/worldcities-pop-lang-rank-sql-create-tbls)
# No 'View more' button found
# Headers found: World-Cities  Pop  Lang  Rank (SQL create tbls) World-Cities  Pop  Lang  Rank (SQL create tbls) Abou...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1700 out of 2400 datasets processed
#
# Processing: Argentina Car Prices (https://www.kaggle.com/datasets/ahmettalhabektas/argentina-car-prices)
# No 'View more' button found
# Headers found: Argentina Car Prices Argentina Car Prices About Dataset Usability License Expected update frequency ...
# About Dataset section found with tag: div
# About Dataset: This dataset comprises various car features obtained through web scraping from a website in Argentin...
# Progress: 1701 out of 2400 datasets processed
#
# Processing: A Comprehensive Clinical & Metabolic Dataset (https://www.kaggle.com/datasets/fatemehmohammadinia/gallstone-dataset)
# No 'View more' button found
# Headers found: A Comprehensive Clinical & Metabolic Dataset A Comprehensive Clinical & Metabolic Dataset About Data...
# About Dataset section found with tag: div
# About Dataset: The clinical dataset was collected from the Internal Medicine Outpatient Clinic of Ankara VM Medical...
# Progress: 1702 out of 2400 datasets processed
#
# Processing: Elliptic Data Set (https://www.kaggle.com/datasets/ellipticco/elliptic-data-set)
# No 'View more' button found
# Headers found: Elliptic Data Set Elliptic Data Set About Dataset Description Content License Usability License Expe...
# About Dataset section found with tag: div
# About Dataset: The Elliptic Data Set maps Bitcoin transactions to real entities belonging to licit categories (exch...
# Progress: 1703 out of 2400 datasets processed
#
# Processing: Meteorite Landings (https://www.kaggle.com/datasets/taylorsamarel/meteorite-landings)
# No 'View more' button found
# Headers found: Meteorite Landings Meteorite Landings About Dataset Usability License Expected update frequency Tags...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1704 out of 2400 datasets processed
#
# Processing: Logistics and supply chain dataset (https://www.kaggle.com/datasets/datasetengineer/logistics-and-supply-chain-dataset)
# No 'View more' button found
# Headers found: Logistics and supply chain dataset Logistics and supply chain dataset About Dataset Usability Licens...
# About Dataset section found with tag: div
# About Dataset: This dataset captures a comprehensive set of logistics and supply chain operations  specifically col...
# Progress: 1705 out of 2400 datasets processed
#
# Processing: Freelancer Earnings & Job Trends (https://www.kaggle.com/datasets/shohinurpervezshohan/freelancer-earnings-and-job-trends)
# No 'View more' button found
# Headers found: Freelancer Earnings & Job Trends Freelancer Earnings & Job Trends About Dataset Freelancer Earnings ...
# About Dataset section found with tag: div
# About Dataset: This dataset provides comprehensive information about freelancer earnings and job trends across vari...
# Progress: 1706 out of 2400 datasets processed
#
# Processing: Diabetes (https://www.kaggle.com/datasets/imtkaggleteam/diabetes)
# No 'View more' button found
# Headers found: Diabetes Diabetes About Dataset Usability License Expected update frequency Tags diabetes.csv(37.07 ...
# About Dataset section found with tag: div
# About Dataset: Dataset Description:Several hundred rural African-American patients were included. The diabetes.csv ...
# Progress: 1707 out of 2400 datasets processed
#
# Processing: Zoo Animal Classification (https://www.kaggle.com/datasets/uciml/zoo-animal-classification)
# No 'View more' button found
# Headers found: Zoo Animal Classification Zoo Animal Classification About Dataset zoo.csv class.csv Acknowledgements...
# About Dataset section found with tag: div
# About Dataset: This dataset consists of 101 animals from a zoo.There are 16 variables with various traits to descri...
# Progress: 1708 out of 2400 datasets processed
#
# Processing: Action Recognization (https://www.kaggle.com/datasets/mynamewhattodo/action-recognization)
# No 'View more' button found
# Headers found: Action Recognization Action Recognization About Dataset Usability License Expected update frequency ...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1709 out of 2400 datasets processed
#
# Processing: FAULTWAVE (https://www.kaggle.com/datasets/aneeshmukkamala/faultwave)
# No 'View more' button found
# Headers found: FAULTWAVE FAULTWAVE About Dataset Usability License Expected update frequency Tags fault_input.npy(8...
# About Dataset section found with tag: div
# About Dataset: Contains these subsets of the OpenFWI dataset. This has both input and output file with the float32 ...
# Progress: 1710 out of 2400 datasets processed
#
# Processing: Traffic Signs Preprocessed (https://www.kaggle.com/datasets/valentynsichkar/traffic-signs-preprocessed)
# No 'View more' button found
# Headers found: Traffic Signs Preprocessed Traffic Signs Preprocessed About Dataset 📰 Related Papers 🎓 Related cours...
# About Dataset section found with tag: div
# About Dataset: Sichkar V. N.Real time detection and classification of traffic signs based on YOLO version 3 algorit...
# Progress: 1711 out of 2400 datasets processed
#
# Processing: housing.csv (https://www.kaggle.com/datasets/huyngohoang/housingcsv)
# No 'View more' button found
# Headers found: housing.csv housing.csv About Dataset Usability License Expected update frequency Tags housing.csv(5...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1712 out of 2400 datasets processed
#
# Processing: Weather Prediction (https://www.kaggle.com/datasets/thedevastator/weather-prediction)
# No 'View more' button found
# Headers found: Weather Prediction Weather Prediction About Dataset Weather prediction dataset A dataset for teachin...
# About Dataset section found with tag: div
# About Dataset: Credit to the original author:The dataset was originally publishedhere Hands-on teaching of modern m...
# Progress: 1713 out of 2400 datasets processed
#
# Processing: Suicide and Depression Detection (https://www.kaggle.com/datasets/nikhileswarkomati/suicide-watch)
# No 'View more' button found
# Headers found: Suicide and Depression Detection Suicide and Depression Detection About Dataset Context Content Cite...
# About Dataset section found with tag: div
# About Dataset: When I thought of building a text classifier to detect Suicide Ideation I couldn't find any public d...
# Progress: 1714 out of 2400 datasets processed
#
# Processing: WikiArt (https://www.kaggle.com/datasets/steubk/wikiart)
# No 'View more' button found
# Headers found: WikiArt WikiArt About Dataset Usability License Expected update frequency Tags classes.csv(12.51 MB)...
# About Dataset section found with tag: div
# About Dataset: Dataset used for traininghttps://archive.org/details/wikiart-stylegan2-conditional-modelby Peter Bay...
# Progress: 1715 out of 2400 datasets processed
#
# Processing: Face Mask Detection ~12K Images Dataset (https://www.kaggle.com/datasets/ashishjangra27/face-mask-12k-images-dataset)
# No 'View more' button found
# Headers found: Face Mask Detection ~12K Images Dataset Face Mask Detection ~12K Images Dataset About Dataset Contex...
# About Dataset section found with tag: div
# About Dataset: This dataset is used for Face Mask Detection Classification with images. The dataset consists of alm...
# Progress: 1716 out of 2400 datasets processed
#
# Processing: IMDB 5000 Movie Dataset (https://www.kaggle.com/datasets/carolzhangdc/imdb-5000-movie-dataset)
# No 'View more' button found
# Headers found: IMDB 5000 Movie Dataset IMDB 5000 Movie Dataset About Dataset Usability License Expected update freq...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1717 out of 2400 datasets processed
#
# Processing: Behavioral Risk Factor Surveillance System (https://www.kaggle.com/datasets/cdc/behavioral-risk-factor-surveillance-system)
# No 'View more' button found
# Headers found: Behavioral Risk Factor Surveillance System Behavioral Risk Factor Surveillance System About Dataset ...
# About Dataset section found with tag: div
# About Dataset: The objective of the BRFSS is to collect uniform  state-specific data on preventive health practices...
# Progress: 1718 out of 2400 datasets processed
#
# Processing: Social_Network_Ads (https://www.kaggle.com/datasets/akram24/social-network-ads)
# No 'View more' button found
# Headers found: Social_Network_Ads Social_Network_Ads About Dataset Usability License Expected update frequency Tags...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1719 out of 2400 datasets processed
#
# Processing: Video Game Console Generations (https://www.kaggle.com/datasets/melissamonfared/video-game-console-generations)
# No 'View more' button found
# Headers found: Video Game Console Generations Video Game Console Generations About Dataset Usability License Expect...
# About Dataset section found with tag: div
# About Dataset: This dataset provides an extensive overview of video game console generations  capturing key details...
# Progress: 1720 out of 2400 datasets processed
#
# Processing: Dog and Cat Detection (https://www.kaggle.com/datasets/andrewmvd/dog-and-cat-detection)
# No 'View more' button found
# Headers found: Dog and Cat Detection Dog and Cat Detection About Dataset About this Data How to Cite this Dataset B...
# About Dataset section found with tag: div
# About Dataset: In reality  the rise of AI is due to us looking for a way to hone our capacity to show love to our p...
# Progress: 1721 out of 2400 datasets processed
#
# Processing: Online Retail Dataset (https://www.kaggle.com/datasets/ulrikthygepedersen/online-retail-dataset)
# No 'View more' button found
# Headers found: Online Retail Dataset Online Retail Dataset About Dataset Usability License Expected update frequenc...
# About Dataset section found with tag: div
# About Dataset: InvoiceNo: Invoice number. Nominal  a 6-digit integral number uniquely assigned to each transaction....
# Progress: 1722 out of 2400 datasets processed
#
# Processing: Smartphones Sales Dataset (https://www.kaggle.com/datasets/yaminh/smartphone-sale-dataset)
# No 'View more' button found
# Headers found: Smartphones Sales Dataset Smartphones Sales Dataset About Dataset Usability License Expected update ...
# About Dataset section found with tag: div
# About Dataset: Description for each of the variables:
# Progress: 1723 out of 2400 datasets processed
#
# Processing: Brain MRI Dataset for Tumor Detection and Analysis (https://www.kaggle.com/datasets/sudipde25/mri-dataset-for-detection-and-analysis)
# No 'View more' button found
# Headers found: Brain MRI Dataset for Tumor Detection and Analysis Brain MRI Dataset for Tumor Detection and Analysi...
# About Dataset section found with tag: div
# About Dataset: OverviewSuch a dataset should support innovative studies in medical imaging  particularly in detecti...
# Progress: 1724 out of 2400 datasets processed
#
# Processing: CovidX-v3-224 (https://www.kaggle.com/datasets/nosignal/covidx-v3-224)
# No 'View more' button found
# Headers found: CovidX-v3-224 CovidX-v3-224 About Dataset Usability License Expected update frequency Tags CovidX_v3...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1725 out of 2400 datasets processed
#
# Processing: Game Recommendations on Steam (https://www.kaggle.com/datasets/antonkozyriev/game-recommendations-on-steam)
# No 'View more' button found
# Headers found: Game Recommendations on Steam Game Recommendations on Steam About Dataset Context Content Acknowledg...
# About Dataset section found with tag: div
# About Dataset: The dataset containsover 41 millioncleaned and preprocessed user recommendations (reviews) from a St...
# Progress: 1726 out of 2400 datasets processed
#
# Processing: ImageNet 1000 (mini) (https://www.kaggle.com/datasets/ifigotin/imagenetmini-1000)
# No 'View more' button found
# Headers found: ImageNet 1000 (mini) ImageNet 1000 (mini) About Dataset Context Acknowledgements Usability License E...
# About Dataset section found with tag: div
# About Dataset: https://github.com/pytorch/examples/tree/master/imagenet https://github.com/pytorch/examples/tree/ma...
# Progress: 1727 out of 2400 datasets processed
#
# Processing: Sleep Cycle & Productivity (https://www.kaggle.com/datasets/adilshamim8/sleep-cycle-and-productivity)
# No 'View more' button found
# Headers found: Sleep Cycle & Productivity Sleep Cycle & Productivity About Dataset 📌Dataset Details 🔍Key Insights f...
# About Dataset section found with tag: div
# About Dataset: You shouldn't take this dataset too seriously; it was created with Python to mimic real-world sleep ...
# Progress: 1728 out of 2400 datasets processed
#
# Processing: ucf101-subset (https://www.kaggle.com/datasets/aisuko/ucf101-subset)
# No 'View more' button found
# Headers found: ucf101-subset ucf101-subset About Dataset Usability License Expected update frequency Tags UCF101_su...
# About Dataset section found with tag: div
# About Dataset: UCF101 - Action Recognition Data Set. Tasks: Video-classificationLicense: Apache-2.0 Original:https:...
# Progress: 1729 out of 2400 datasets processed
#
# Processing: poverty in Latin America (https://www.kaggle.com/datasets/willianoliveiragibin/poverty-in-latin-america)
# No 'View more' button found
# Headers found: poverty in Latin America poverty in Latin America About Dataset Usability License Expected update fr...
# About Dataset section found with tag: div
# About Dataset: The first chart shows how the surveyed people answered the following question: “In the last 20 years...
# Progress: 1730 out of 2400 datasets processed
#
# Processing: Luna16 (https://www.kaggle.com/datasets/avc0706/luna16)
# No 'View more' button found
# Headers found: Luna16 Luna16 About Dataset About the data This dataset contains the download data for the LUNA16 ch...
# About Dataset section found with tag: div
# About Dataset: The publicly available LIDC/IDRI database. This data uses the Creative Commons Attribution 3.0 Unpor...
# Progress: 1731 out of 2400 datasets processed
#
# Processing: Cervical Cancer largest dataset (SipakMed) (https://www.kaggle.com/datasets/prahladmehandiratta/cervical-cancer-largest-dataset-sipakmed)
# No 'View more' button found
# Headers found: Cervical Cancer largest dataset (SipakMed) Cervical Cancer largest dataset (SipakMed) About Dataset ...
# About Dataset section found with tag: div
# About Dataset: Please don't forget to upvote if you find this useful. Cervical cancer is the fourth most common can...
# Progress: 1732 out of 2400 datasets processed
#
# Processing: openvino-lib (https://www.kaggle.com/datasets/arsenypoyda/openvino-lib)
# No 'View more' button found
# Headers found: openvino-lib openvino-lib About Dataset Usability License Expected update frequency Tags openvino-20...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1733 out of 2400 datasets processed
#
# Processing: Bank_Loan_modelling (https://www.kaggle.com/datasets/itsmesunil/bank-loan-modelling)
# No 'View more' button found
# Headers found: Bank_Loan_modelling Bank_Loan_modelling About Dataset Context Content Acknowledgements Inspiration U...
# About Dataset section found with tag: div
# About Dataset: This case is about a bank (Thera Bank) which has a growing customer base. Majority of these customer...
# Progress: 1734 out of 2400 datasets processed
#
# Processing: Trump Speeches (audio and word transcription) (https://www.kaggle.com/datasets/etaifour/trump-speeches-audio-and-word-transcription)
# No 'View more' button found
# Headers found: Trump Speeches (audio and word transcription) Trump Speeches (audio and word transcription) About Da...
# About Dataset section found with tag: div
# About Dataset: These files are scrapped from youtube and where annoted using an online tool. They could be a perfec...
# Progress: 1735 out of 2400 datasets processed
#
# Processing: Sales Data Analysis (https://www.kaggle.com/datasets/beekiran/sales-data-analysis)
# No 'View more' button found
# Headers found: Sales Data Analysis Sales Data Analysis About Dataset Sales Analysis About the Dataset Acknowledgeme...
# About Dataset section found with tag: div
# About Dataset: The dataset consists of 11 columns  each column representing an attribute of purchase on a product -...
# Progress: 1736 out of 2400 datasets processed
#
# Processing: Dallas Crime and Police Reports (https://www.kaggle.com/datasets/taylorsamarel/dallas-crime-and-police-reports)
# No 'View more' button found
# Headers found: Dallas Crime and Police Reports Dallas Crime and Police Reports About Dataset Usability License Expe...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1737 out of 2400 datasets processed
#
# Processing: DeepGlobe Land Cover Classification Dataset (https://www.kaggle.com/datasets/balraj98/deepglobe-land-cover-classification-dataset)
# No 'View more' button found
# Headers found: DeepGlobe Land Cover Classification Dataset DeepGlobe Land Cover Classification Dataset About Datase...
# About Dataset section found with tag: div
# About Dataset: Automatic categorization and segmentation of land cover is of great importance for sustainable devel...
# Progress: 1738 out of 2400 datasets processed
#
# Processing: Wind Turbine Scada Dataset (https://www.kaggle.com/datasets/berkerisen/wind-turbine-scada-dataset)
# No 'View more' button found
# Headers found: Wind Turbine Scada Dataset Wind Turbine Scada Dataset About Dataset Context Content Usability Licens...
# About Dataset section found with tag: div
# About Dataset: In Wind Turbines  Scada Systems measure and save data's like wind speed  wind direction  generated p...
# Progress: 1739 out of 2400 datasets processed
#
# Processing: Crypto currencies daily prices (https://www.kaggle.com/datasets/svaningelgem/crypto-currencies-daily-prices)
# No 'View more' button found
# Headers found: Crypto currencies daily prices Crypto currencies daily prices About Dataset Usability License Expect...
# About Dataset section found with tag: div
# About Dataset: Most famous crypto currencies by market cap. "Crypto" is a shorthand term for "cryptocurrency " whic...
# Progress: 1740 out of 2400 datasets processed
#
# Processing: Email Spam Detection Dataset (classification) (https://www.kaggle.com/datasets/shantanudhakadd/email-spam-detection-dataset-classification)
# No 'View more' button found
# Headers found: Email Spam Detection Dataset (classification) Email Spam Detection Dataset (classification) About Da...
# About Dataset section found with tag: div
# About Dataset: TO CLASSIFY THE MAIL AS SPAM OR HAM BY USING MACHINE OR DEEP LEARNING MODEL. This is the dataset in ...
# Progress: 1741 out of 2400 datasets processed
#
# Processing: IMC2024_pipelines (https://www.kaggle.com/datasets/kashiwaba/imc2024-pipelines)
# No 'View more' button found
# Headers found: IMC2024_pipelines IMC2024_pipelines About Dataset Usability License Expected update frequency Tags e...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1742 out of 2400 datasets processed
#
# Processing: Organic Carbon & Dissolved Organic Carbon (https://www.kaggle.com/datasets/melissamonfared/organic-carbon-and-dissolved-organic-carbon)
# No 'View more' button found
# Headers found: Organic Carbon & Dissolved Organic Carbon Organic Carbon & Dissolved Organic Carbon About Dataset Us...
# About Dataset section found with tag: div
# About Dataset: Total Organic Carbon (TOC) and Dissolved Organic Carbon (DOC) are critical metrics for evaluating wa...
# Progress: 1743 out of 2400 datasets processed
#
# Processing: Fertilizer Prediction (https://www.kaggle.com/datasets/gdabhishek/fertilizer-prediction)
# No 'View more' button found
# Headers found: Fertilizer Prediction Fertilizer Prediction About Dataset Context Usability License Expected update ...
# About Dataset section found with tag: div
# About Dataset: Here is the data of various fertilizers information.This data was by researching various websites an...
# Progress: 1744 out of 2400 datasets processed
#
# Processing: Brain Tumor MRI Multi-Class Dataset (https://www.kaggle.com/datasets/maxwellbernard/brain-tumor-mri-multi-class-dataset)
# No 'View more' button found
# Headers found: Brain Tumor MRI Multi-Class Dataset Brain Tumor MRI Multi-Class Dataset About Dataset Key Notes: Rec...
# About Dataset section found with tag: div
# About Dataset: This dataset consolidates brain tumor MRI images from multiple Kaggle data sources to create a large...
# Progress: 1745 out of 2400 datasets processed
#
# Processing: Emotion Dataset for Emotion Recognition Tasks (https://www.kaggle.com/datasets/parulpandey/emotion-dataset)
# No 'View more' button found
# Headers found: Emotion Dataset for Emotion Recognition Tasks Emotion Dataset for Emotion Recognition Tasks About Da...
# About Dataset section found with tag: div
# About Dataset: A dataset of English Twitter messages with six basic emotions: anger  fear  joy  love  sadness  and ...
# Progress: 1746 out of 2400 datasets processed
#
# Processing: Celebrity Face Image Dataset (https://www.kaggle.com/datasets/vishesh1412/celebrity-face-image-dataset)
# No 'View more' button found
# Headers found: Celebrity Face Image Dataset Celebrity Face Image Dataset About Dataset Usability License Expected u...
# About Dataset section found with tag: div
# About Dataset: This dataset contains images of 18 Hollywood celebrities with 100 images of each celebrity. The peop...
# Progress: 1747 out of 2400 datasets processed
#
# Processing: E-commerce dataset by Olist (SQLite) (https://www.kaggle.com/datasets/terencicp/e-commerce-dataset-by-olist-as-an-sqlite-database)
# No 'View more' button found
# Headers found: E-commerce dataset by Olist (SQLite) E-commerce dataset by Olist (SQLite) About Dataset Usability Li...
# About Dataset section found with tag: div
# About Dataset: I imported the two Olist Kaggle datasets into an SQLite database. I modified the original table name...
# Progress: 1748 out of 2400 datasets processed
#
# Processing: Loan Data (https://www.kaggle.com/datasets/itssuru/loan-data)
# No 'View more' button found
# Headers found: Loan Data Loan Data About Dataset About the data and what to do… Usability License Expected update f...
# About Dataset section found with tag: div
# About Dataset: publicly available data from LendingClub.com. Lending Club connects people who need money (borrowers...
# Progress: 1749 out of 2400 datasets processed
#
# Processing: Australia Companies Dataset (https://www.kaggle.com/datasets/migrantworkerdatahub/australia-companies-dataset)
# No 'View more' button found
# Headers found: Australia Companies Dataset Australia Companies Dataset About Dataset Usability License Expected upd...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1750 out of 2400 datasets processed
#
# Processing: Advertising.csv (https://www.kaggle.com/datasets/bumba5341/advertisingcsv)
# No 'View more' button found
# Headers found: Advertising.csv Advertising.csv About Dataset Usability License Expected update frequency Tags Adver...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1751 out of 2400 datasets processed
#
# Processing: Suicide Rates Overview 1985 to 2016  (https://www.kaggle.com/datasets/russellyates88/suicide-rates-overview-1985-to-2016)
# No 'View more' button found
# Headers found: Suicide Rates Overview 1985 to 2016 Suicide Rates Overview 1985 to 2016 About Dataset Content Refere...
# About Dataset section found with tag: div
# About Dataset: This compiled dataset pulled from four other datasets linked by time and place  and was built to fin...
# Progress: 1752 out of 2400 datasets processed
#
# Processing: CarDekho Used Car Dataset (https://www.kaggle.com/datasets/manishkr1754/cardekho-used-car-data)
# No 'View more' button found
# Headers found: CarDekho Used Car Dataset CarDekho Used Car Dataset About Dataset Usability License Update frequency...
# About Dataset section found with tag: div
# About Dataset: The used car market in India is a dynamic and ever-changing landscape. Prices can fluctuate wildly b...
# Progress: 1753 out of 2400 datasets processed
#
# Processing: Kornia Local Feature model weights (https://www.kaggle.com/datasets/oldufo/kornia-local-feature-weights)
# No 'View more' button found
# Headers found: Kornia Local Feature model weights Kornia Local Feature model weights About Dataset Usability Licens...
# About Dataset section found with tag: div
# About Dataset: Weights for the patch-based kornia local feature descriptors  such as HardNet  SoSNet  etc.
# Progress: 1754 out of 2400 datasets processed
#
# Processing: Chest X-ray (Covid-19 & Pneumonia) (https://www.kaggle.com/datasets/prashant268/chest-xray-covid19-pneumonia)
# No 'View more' button found
# Headers found: Chest X-ray (Covid-19 & Pneumonia) Chest X-ray (Covid-19 & Pneumonia) About Dataset Context Content ...
# About Dataset section found with tag: div
# About Dataset: COVID-19 (coronavirus disease 2019)is an infectious disease caused bysevere acute respiratory syndro...
# Progress: 1755 out of 2400 datasets processed
#
# Processing: DeepSig Dataset: RadioML 2018.01A (https://www.kaggle.com/datasets/pinxau1000/radioml2018)
# No 'View more' button found
# Headers found: DeepSig Dataset: RadioML 2018.01A DeepSig Dataset: RadioML 2018.01A About Dataset 1. Context 2. Cont...
# About Dataset section found with tag: div
# About Dataset: Deepsig Inc.has created a small corpus of standard datasets which can be used for original and repro...
# Progress: 1756 out of 2400 datasets processed
#
# Processing: Financial Fraud Detection Dataset (https://www.kaggle.com/datasets/sriharshaeedala/financial-fraud-detection-dataset)
# No 'View more' button found
# Headers found: Financial Fraud Detection Dataset Financial Fraud Detection Dataset About Dataset Dataset Overview I...
# About Dataset section found with tag: div
# About Dataset: This dataset presents a synthetic representation of mobile money transactions  meticulously crafted ...
# Progress: 1757 out of 2400 datasets processed
#
# Processing: Air Passengers (https://www.kaggle.com/datasets/chirag19/air-passengers)
# No 'View more' button found
# Headers found: Air Passengers Air Passengers About Dataset Usability License Expected update frequency Tags AirPass...
# About Dataset section found with tag: div
# About Dataset: This dataset provides monthly totals of a US airline passengers from 1949 to 1960. This dataset is t...
# Progress: 1758 out of 2400 datasets processed
#
# Processing: 1.3M Linkedin Jobs & Skills (2024) (https://www.kaggle.com/datasets/asaniczka/1-3m-linkedin-jobs-and-skills-2024)
# No 'View more' button found
# Headers found: 1.3M Linkedin Jobs & Skills (2024) 1.3M Linkedin Jobs & Skills (2024) About Dataset Interesting Task...
# About Dataset section found with tag: div
# About Dataset: LinkedIn is a widely used professional networking platform that hosts millions of job postings. This...
# Progress: 1759 out of 2400 datasets processed
#
# Processing: Synthetic Circle Dataset (https://www.kaggle.com/datasets/shivamarora384/synthetic-circle-dataset)
# No 'View more' button found
# Headers found: Synthetic Circle Dataset Synthetic Circle Dataset About Dataset Usability License Expected update fr...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1760 out of 2400 datasets processed
#
# Processing: CIFAR-10 (https://www.kaggle.com/datasets/ayush1220/cifar10)
# No 'View more' button found
# Headers found: CIFAR-10 CIFAR-10 About Dataset Context Content Acknowledgements Usability License Expected update f...
# About Dataset section found with tag: div
# About Dataset: The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes  with 6000 images per class...
# Progress: 1761 out of 2400 datasets processed
#
# Processing: sample_dataset (https://www.kaggle.com/datasets/mynamewhattodo/sample-dataset)
# No 'View more' button found
# Headers found: sample_dataset sample_dataset About Dataset Usability License Expected update frequency Tags Creditc...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1762 out of 2400 datasets processed
#
# Processing: Music Genre Classification (https://www.kaggle.com/datasets/purumalgi/music-genre-classification)
# No 'View more' button found
# Headers found: Music Genre Classification Music Genre Classification About Dataset Context Content Acknowledgements...
# About Dataset section found with tag: div
# About Dataset: Dataset is acquired from one of theMachineHack Hackathon Training dataset: 17 996 rows with 17 colum...
# Progress: 1763 out of 2400 datasets processed
#
# Processing: MNIST as .jpg (https://www.kaggle.com/datasets/scolianni/mnistasjpg)
# No 'View more' button found
# Headers found: MNIST as .jpg MNIST as .jpg About Dataset Context Content Acknowledgements Inspiration Usability Lic...
# About Dataset section found with tag: div
# About Dataset: TheDigit Recognizercompetition uses the popular MNIST dataset to challenge Kagglers to classify digi...
# Progress: 1764 out of 2400 datasets processed
#
# Processing: Spotify dataset  (https://www.kaggle.com/datasets/ambaliyagati/spotify-dataset-for-playing-around-with-sql)
# No 'View more' button found
# Headers found: Spotify dataset Spotify dataset About Dataset Description for Spotify Songs Dataset on Kaggle Datase...
# About Dataset section found with tag: div
# About Dataset: Description:This dataset contains a collection of songs fetched from the Spotify API  covering vario...
# Progress: 1765 out of 2400 datasets processed
#
# Processing: Oral Diseases  (https://www.kaggle.com/datasets/salmansajid05/oral-diseases)
# No 'View more' button found
# Headers found: Oral Diseases Oral Diseases About Dataset Usability License Expected update frequency Tags Calculus(...
# About Dataset section found with tag: div
# About Dataset: Dental Condition DatasetThe Dental Condition Dataset is a comprehensive collection of images specifi...
# Progress: 1766 out of 2400 datasets processed
#
# Processing: Vehicle Dataset for YOLO (https://www.kaggle.com/datasets/nadinpethiyagoda/vehicle-dataset-for-yolo)
# No 'View more' button found
# Headers found: Vehicle Dataset for YOLO Vehicle Dataset for YOLO About Dataset Usability License Expected update fr...
# About Dataset section found with tag: div
# About Dataset: This dataset contians labelled vehicle images gathered from Kaggle  Standford Car Dataset and Web sc...
# Progress: 1767 out of 2400 datasets processed
#
# Processing: Boston Airbnb Open Data (https://www.kaggle.com/datasets/airbnb/boston)
# No 'View more' button found
# Headers found: Boston Airbnb Open Data Boston Airbnb Open Data About Dataset Context Content Inspiration Acknowledg...
# About Dataset section found with tag: div
# About Dataset: Since 2008  guests and hosts have used Airbnb to travel in a more unique  personalized way. As part ...
# Progress: 1768 out of 2400 datasets processed
#
# Processing: NBA Stats (1947-present) (https://www.kaggle.com/datasets/sumitrodatta/nba-aba-baa-stats)
# No 'View more' button found
# Headers found: NBA Stats (1947-present) NBA Stats (1947-present) About Dataset Context Content Acknowledgements Usa...
# About Dataset section found with tag: div
# About Dataset: When I set out to gather data for my first NBA-related project  I used the IMPORTHTML function from ...
# Progress: 1769 out of 2400 datasets processed
#
# Processing: Earthquake dataset (https://www.kaggle.com/datasets/warcoder/earthquake-dataset)
# No 'View more' button found
# Headers found: Earthquake dataset Earthquake dataset About Dataset Usability License Expected update frequency Tags...
# About Dataset section found with tag: div
# About Dataset: Datasets contain records of 782 earthquakes from 1/1/2001 to 1/1/2023. The meaning of all columns is...
# Progress: 1770 out of 2400 datasets processed
#
# Processing: Student Performance & Learning Style (https://www.kaggle.com/datasets/adilshamim8/student-performance-and-learning-style)
# No 'View more' button found
# Headers found: Student Performance & Learning Style Student Performance & Learning Style About Dataset About the Da...
# About Dataset section found with tag: div
# About Dataset: You should not take this dataset seriously  as it is a synthetic representation based on true trends...
# Progress: 1771 out of 2400 datasets processed
#
# Processing: Gender Classification Dataset (https://www.kaggle.com/datasets/elakiricoder/gender-classification-dataset)
# No 'View more' button found
# Headers found: Gender Classification Dataset Gender Classification Dataset About Dataset Context Content Acknowledg...
# About Dataset section found with tag: div
# About Dataset: While I was practicing machine learning  I wanted to create a simple dataset that is closely aligned...
# Progress: 1772 out of 2400 datasets processed
#
# Processing: Flight Delay and Cancellation Dataset (2019-2023) (https://www.kaggle.com/datasets/patrickzel/flight-delay-and-cancellation-dataset-2019-2023)
# No 'View more' button found
# Headers found: Flight Delay and Cancellation Dataset (2019-2023) Flight Delay and Cancellation Dataset (2019-2023) ...
# About Dataset section found with tag: div
# About Dataset: Airline Flight Delay and Cancellation Data  August 2019 - August 2023 US Department of Transportatio...
# Progress: 1773 out of 2400 datasets processed
#
# Processing: MNIST Digit Recognizer (https://www.kaggle.com/datasets/animatronbot/mnist-digit-recognizer)
# No 'View more' button found
# Headers found: MNIST Digit Recognizer MNIST Digit Recognizer About Dataset Usability License Expected update freque...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1774 out of 2400 datasets processed
#
# Processing: IMC2024_pipelines_v7 (https://www.kaggle.com/datasets/igorlashkov/imc2024-pipelines-v7)
# No 'View more' button found
# Headers found: IMC2024_pipelines_v7 IMC2024_pipelines_v7 About Dataset Usability License Expected update frequency ...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1775 out of 2400 datasets processed
#
# Processing: 🍌 | Banana Quality (https://www.kaggle.com/datasets/l3llff/banana)
# No 'View more' button found
# Headers found: 🍌 | Banana Quality 🍌 | Banana Quality About Dataset Content Columns Usability License Expected updat...
# About Dataset section found with tag: div
# About Dataset: Tabular dataset contains numerical information about bananas of different quality (size  weight  swe...
# Progress: 1776 out of 2400 datasets processed
#
# Processing: Remote Work & Mental Health 🌍🧠 (https://www.kaggle.com/datasets/waqi786/remote-work-and-mental-health)
# No 'View more' button found
# Headers found: Remote Work & Mental Health 🌍🧠 Remote Work & Mental Health 🌍🧠 About Dataset Usability License Expect...
# About Dataset section found with tag: div
# About Dataset: As remote work continues to shape modern workplaces  understanding its effects on mental health  str...
# Progress: 1777 out of 2400 datasets processed
#
# Processing: Wine Quality (https://www.kaggle.com/datasets/rajyellow46/wine-quality)
# No 'View more' button found
# Headers found: Wine Quality Wine Quality About Dataset Usability License Expected update frequency Tags winequality...
# About Dataset section found with tag: div
# About Dataset: Data Set Information: The dataset was downloaded from the UCI Machine Learning Repository. The two d...
# Progress: 1778 out of 2400 datasets processed
#
# Processing: Penguin Sizes Dataset (https://www.kaggle.com/datasets/amulyas/penguin-size-dataset)
# No 'View more' button found
# Headers found: Penguin Sizes Dataset Penguin Sizes Dataset About Dataset Usability License Equivalent Dataset Expec...
# About Dataset section found with tag: div
# About Dataset: This is meant to be a fun dataset for you to learn on and use it as something to play around with. T...
# Progress: 1779 out of 2400 datasets processed
#
# Processing: Body Fat Prediction Dataset (https://www.kaggle.com/datasets/fedesoriano/body-fat-prediction-dataset)
# No 'View more' button found
# Headers found: Body Fat Prediction Dataset Body Fat Prediction Dataset About Dataset Context Educational use of the...
# About Dataset section found with tag: div
# About Dataset: Lists estimates of the percentage of body fat determined by underwaterweighing and various body circ...
# Progress: 1780 out of 2400 datasets processed
#
# Processing: Leprosy Chronic Wound Images (CO2Wounds-V2) (https://www.kaggle.com/datasets/orvile/leprosy-chronic-wound-images-co2wounds-v2)
# No 'View more' button found
# Headers found: Leprosy Chronic Wound Images (CO2Wounds-V2) Leprosy Chronic Wound Images (CO2Wounds-V2) About Datase...
# About Dataset section found with tag: div
# About Dataset: DOI LinkLicense Details Dive intoCO2Wounds-V2  a dataset featuring764 chronic wound imagesfrom lepro...
# Progress: 1781 out of 2400 datasets processed
#
# Processing: Face Mask Detection Dataset (https://www.kaggle.com/datasets/wobotintelligence/face-mask-detection-dataset)
# No 'View more' button found
# Headers found: Face Mask Detection Dataset Face Mask Detection Dataset About Dataset Usability License Expected upd...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1782 out of 2400 datasets processed
#
# Processing: Pokemon Images Dataset (https://www.kaggle.com/datasets/kvpratama/pokemon-images-dataset)
# No 'View more' button found
# Headers found: Pokemon Images Dataset Pokemon Images Dataset About Dataset Context Content Acknowledgements Inspira...
# About Dataset section found with tag: div
# About Dataset: I collected this dataset for my school project. The project is to train GAN to generate new Pokemon....
# Progress: 1783 out of 2400 datasets processed
#
# Processing: EA Sports FC 24 complete player dataset (https://www.kaggle.com/datasets/stefanoleone992/ea-sports-fc-24-complete-player-dataset)
# No 'View more' button found
# Headers found: EA Sports FC 24 complete player dataset EA Sports FC 24 complete player dataset About Dataset Contex...
# About Dataset section found with tag: div
# About Dataset: The datasets provided include the players data for the Career Mode from FIFA 15 to EA Sports FC 24. ...
# Progress: 1784 out of 2400 datasets processed
#
# Processing: Plant Destruction and Environmental Pollution (https://www.kaggle.com/datasets/khushikyad001/plant-destruction-and-environmental-pollution)
# No 'View more' button found
# Headers found: Plant Destruction and Environmental Pollution Plant Destruction and Environmental Pollution About Da...
# About Dataset section found with tag: div
# About Dataset: This dataset represents a realistic simulation of environmental destruction events in India  highlig...
# Progress: 1785 out of 2400 datasets processed
#
# Processing: RWFork: Russian Wikipedia Fork Edits Dataset (https://www.kaggle.com/datasets/kosovanolexandr/rwfork-russian-wikipedia-fork-edits-dataset)
# No 'View more' button found
# Headers found: RWFork: Russian Wikipedia Fork Edits Dataset RWFork: Russian Wikipedia Fork Edits Dataset About Data...
# About Dataset section found with tag: div
# About Dataset: Description This dataset contains the edits made by editors of the Russian Wikipedia Fork (RWFork  r...
# Progress: 1786 out of 2400 datasets processed
#
# Processing: 515K Hotel Reviews Data in Europe (https://www.kaggle.com/datasets/jiashenliu/515k-hotel-reviews-data-in-europe)
# No 'View more' button found
# Headers found: 515K Hotel Reviews Data in Europe 515K Hotel Reviews Data in Europe About Dataset Acknowledgements D...
# About Dataset section found with tag: div
# About Dataset: The data was scraped fromBooking.com. All data in the file is publicly available to everyone already...
# Progress: 1787 out of 2400 datasets processed
#
# Processing: Face Mask Detection (https://www.kaggle.com/datasets/vijaykumar1799/face-mask-detection)
# No 'View more' button found
# Headers found: Face Mask Detection Face Mask Detection About Dataset Context Content Acknowledgements Usability Lic...
# About Dataset section found with tag: div
# About Dataset: Having seen multiple datasets related to face mask detection on Kaggle  one dataset which stood out ...
# Progress: 1788 out of 2400 datasets processed
#
# Processing: Regional Indian Superstitions & Beliefs (https://www.kaggle.com/datasets/antrabansal/regional-indian-superstitions)
# No 'View more' button found
# Headers found: Regional Indian Superstitions & Beliefs Regional Indian Superstitions & Beliefs About Dataset Usabil...
# About Dataset section found with tag: div
# About Dataset: India is a land of rich cultural diversity  with countless regional traditions  folklores  and super...
# Progress: 1789 out of 2400 datasets processed
#
# Processing: bone-marrow-cell-classification (https://www.kaggle.com/datasets/donajui/bone-marrow-cell-classification)
# No 'View more' button found
# Headers found: bone-marrow-cell-classification bone-marrow-cell-classification About Dataset Usability License Expe...
# About Dataset section found with tag: div
# About Dataset: This dataset contains 7 000 labeled images of white blood cells  divided into 7 distinct classes bas...
# Progress: 1790 out of 2400 datasets processed
#
# Processing: LMSYS wheel files (https://www.kaggle.com/datasets/emiz6413/lmsys-wheel-files)
# No 'View more' button found
# Headers found: LMSYS wheel files LMSYS wheel files About Dataset Usability License Expected update frequency Tags M...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 1791 out of 2400 datasets processed
#
# Processing: Forest Cover Type Dataset (https://www.kaggle.com/datasets/uciml/forest-cover-type-dataset)
# No 'View more' button found
# Headers found: Forest Cover Type Dataset Forest Cover Type Dataset About Dataset Context Content Acknowledgement In...
# About Dataset section found with tag: div
# About Dataset: This dataset contains tree observations from four areas of the Roosevelt National Forest in Colorado...
# Progress: 1792 out of 2400 datasets processed
#
# Processing: Wikipedia Movie Plots (https://www.kaggle.com/datasets/jrobischon/wikipedia-movie-plots)
# No 'View more' button found
# Headers found: Wikipedia Movie Plots Wikipedia Movie Plots About Dataset Context Content Inspiration Acknowledgemen...
# About Dataset section found with tag: div
# About Dataset: Plot summary descriptions scraped from Wikipedia The dataset contains descriptions of 34 886 movies ...
# ...
# Progress: 2366 out of 2400 datasets processed
#
# Processing: Give Me Some Credit :: 2011 Competition Data (https://www.kaggle.com/datasets/brycecf/give-me-some-credit-dataset)
# No 'View more' button found
# Headers found: Give Me Some Credit :: 2011 Competition Data Give Me Some Credit :: 2011 Competition Data About Data...
# About Dataset section found with tag: div
# About Dataset: I noticed that the data sets for old Kaggle competitions (at least the ones that still permit submis...
# Progress: 2367 out of 2400 datasets processed
#
# Processing: Cell Towers Worldwide: Location Data by Continent (https://www.kaggle.com/datasets/zakariaeyoussefi/cell-towers-worldwide-location-data-by-continent)
# No 'View more' button found
# Headers found: Cell Towers Worldwide: Location Data by Continent Cell Towers Worldwide: Location Data by Continent ...
# About Dataset section found with tag: div
# About Dataset: This extensive dataset provides geographic coordinates and network information for cell tower locati...
# Progress: 2368 out of 2400 datasets processed
#
# Processing: Fire and Smoke Dataset (https://www.kaggle.com/datasets/dataclusterlabs/fire-and-smoke-dataset)
# No 'View more' button found
# Headers found: Fire and Smoke Dataset Fire and Smoke Dataset About Dataset This dataset is collected by DataCluster...
# About Dataset section found with tag: div
# About Dataset: This dataset is an extremely challenging set of over 7000+ original Fire and Smoke images captured a...
# Progress: 2369 out of 2400 datasets processed
#
# Processing: Ford Car Price Prediction (https://www.kaggle.com/datasets/adhurimquku/ford-car-price-prediction)
# No 'View more' button found
# Headers found: Ford Car Price Prediction Ford Car Price Prediction About Dataset Usability License Expected update ...
# About Dataset section found with tag: div
# About Dataset: Attribute Information:1.model - > Ford Car Brands2.year   - >Production Year3.price  - >Price of car...
# Progress: 2370 out of 2400 datasets processed
#
# Processing: All Space Missions from 1957 (https://www.kaggle.com/datasets/agirlcoding/all-space-missions-from-1957)
# No 'View more' button found
# Headers found: All Space Missions from 1957 All Space Missions from 1957 About Dataset Usability License Expected u...
# About Dataset section found with tag: div
# About Dataset: Who does not love Space?This DataSet was scraped fromhttps://nextspaceflight.com/launches/past/?page...
# Progress: 2371 out of 2400 datasets processed
#
# Processing: Predictive Maintenance Dataset (https://www.kaggle.com/datasets/hiimanshuagarwal/predictive-maintenance-dataset)
# No 'View more' button found
# Headers found: Predictive Maintenance Dataset Predictive Maintenance Dataset About Dataset Usability License Expect...
# About Dataset section found with tag: div
# About Dataset: A company has a fleet of devices transmitting daily sensor readings. They would like to create a pre...
# Progress: 2372 out of 2400 datasets processed
#
# Processing: Job Listings (https://www.kaggle.com/datasets/navneetkaurbrarr/job-listings)
# No 'View more' button found
# Headers found: Job Listings Job Listings About Dataset Usability License Expected update frequency Tags job_listing...
# About Dataset section found with tag: div
# About Dataset: Consists of 500 job openings across various industries. Each record includes a job ID  job title (Da...
# Progress: 2373 out of 2400 datasets processed
#
# Processing: SQL Murder Mystery Database (https://www.kaggle.com/datasets/johnp47/sql-murder-mystery-database)
# No 'View more' button found
# Headers found: SQL Murder Mystery Database SQL Murder Mystery Database About Dataset Usability License Expected upd...
# About Dataset section found with tag: div
# About Dataset: There's been a Murder in SQL City! The SQL Murder Mystery is designed to be both a self-directed les...
# Progress: 2374 out of 2400 datasets processed
#
# Processing: Diabetes  Hypertension and Stroke Prediction (https://www.kaggle.com/datasets/prosperchuks/health-dataset)
# No 'View more' button found
# Headers found: Diabetes  Hypertension and Stroke Prediction Diabetes  Hypertension and Stroke Prediction About Data...
# About Dataset section found with tag: div
# About Dataset: All datasets are cleaned  augmented  and have balanced classes. Data Sources:diabetes_data hypertens...
# Progress: 2375 out of 2400 datasets processed
#
# Processing: English Handwritten Characters (https://www.kaggle.com/datasets/dhruvildave/english-handwritten-characters-dataset)
# No 'View more' button found
# Headers found: English Handwritten Characters English Handwritten Characters About Dataset Introduction Citation Us...
# About Dataset section found with tag: div
# About Dataset: This dataset contains 3 410 images of handwritten characters in English. This is a classification da...
# Progress: 2376 out of 2400 datasets processed
#
# Processing: Income classification (https://www.kaggle.com/datasets/lodetomasi1995/income-classification)
# No 'View more' button found
# Headers found: Income classification Income classification About Dataset Usability License Expected update frequenc...
# About Dataset section found with tag: div
# About Dataset: Listing of attributes: 50K  <=50K. age: continuous.workclass: Private  Self-emp-not-inc  Self-emp-in...
# Progress: 2377 out of 2400 datasets processed
#
# Processing: Sephora Skincare Reviews (https://www.kaggle.com/datasets/melissamonfared/sephora-skincare-reviews)
# No 'View more' button found
# Headers found: Sephora Skincare Reviews Sephora Skincare Reviews About Dataset Usability License Expected update fr...
# About Dataset section found with tag: div
# About Dataset: Please note that the original dataset was uploaded by nadyinky on Kaggle and is accessible through t...
# Progress: 2378 out of 2400 datasets processed
#
# Processing: 2022-2023 Football Player Stats (https://www.kaggle.com/datasets/vivovinco/20222023-football-player-stats)
# No 'View more' button found
# Headers found: 2022-2023 Football Player Stats 2022-2023 Football Player Stats About Dataset Context Content Acknow...
# About Dataset section found with tag: div
# About Dataset: This dataset contains 2022-2023 football player stats per 90 minutes.Only players of Premier League ...
# Progress: 2379 out of 2400 datasets processed
#
# Processing: coco128 (https://www.kaggle.com/datasets/ultralytics/coco128)
# No 'View more' button found
# Headers found: coco128 coco128 About Dataset Usability License Expected update frequency Tags coco128(2 directories...
# About Dataset section found with tag: div
# About Dataset: This dataset contains the first 128 images of COCO train 2017. It is used as the tutorial dataset fo...
# Progress: 2380 out of 2400 datasets processed
#
# Processing: Salary by Job Title and Country (https://www.kaggle.com/datasets/amirmahdiabbootalebi/salary-by-job-title-and-country)
# No 'View more' button found
# Headers found: Salary by Job Title and Country Salary by Job Title and Country About Dataset Usability License Expe...
# About Dataset section found with tag: div
# About Dataset: This dataset provides a comprehensive collection of salary information from various industries and r...
# Progress: 2381 out of 2400 datasets processed
#
# Processing: Bakery Sales (https://www.kaggle.com/datasets/hosubjeong/bakery-sales)
# No 'View more' button found
# Headers found: Bakery Sales Bakery Sales About Dataset Context Content Usability License Expected update frequency ...
# About Dataset section found with tag: div
# About Dataset: I worked part-time at a small bakery in Korea.Our bakery started the delivery service in July 2019.O...
# Progress: 2382 out of 2400 datasets processed
#
# Processing: McDonald's Store Reviews (https://www.kaggle.com/datasets/nelgiriyewithana/mcdonalds-store-reviews)
# No 'View more' button found
# Headers found: McDonald's Store Reviews McDonald's Store Reviews About Dataset Description: Key Features: Potential...
# About Dataset section found with tag: div
# About Dataset: This dataset contains over 33 000 anonymized reviews of McDonald's stores in the United States  scra...
# Progress: 2383 out of 2400 datasets processed
#
# Processing: Retail Store Sales Transactions (Scanner Data) (https://www.kaggle.com/datasets/marian447/retail-store-sales-transactions)
# No 'View more' button found
# Headers found: Retail Store Sales Transactions (Scanner Data) Retail Store Sales Transactions (Scanner Data) About ...
# About Dataset section found with tag: div
# About Dataset: Detailed data on sales of consumer goods obtained by ‘scanning’ the bar codes for individual product...
# Progress: 2384 out of 2400 datasets processed
#
# Processing: California Water Rights Complaints (https://www.kaggle.com/datasets/taylorsamarel/california-water-rights-complaints)
# No 'View more' button found
# Headers found: California Water Rights Complaints California Water Rights Complaints About Dataset Usability Licens...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 2385 out of 2400 datasets processed
#
# Processing: Visual Analysis of S_and_P 500 Sectors (https://www.kaggle.com/datasets/abhinavrongala/visual-analysis-of-s-and-p-500-sectors)
# No 'View more' button found
# Headers found: Visual Analysis of S_and_P 500 Sectors Visual Analysis of S_and_P 500 Sectors About Dataset Usabilit...
# About Dataset section found with tag: div
# About Dataset: This dataset provides a sector-wise summary of companies listed in the S&P 500 index  including thei...
# Progress: 2386 out of 2400 datasets processed
#
# Processing: Obesity or CVD risk (Classify/Regressor/Cluster) (https://www.kaggle.com/datasets/aravindpcoder/obesity-or-cvd-risk-classifyregressorcluster)
# No 'View more' button found
# Headers found: Obesity or CVD risk (Classify/Regressor/Cluster) Obesity or CVD risk (Classify/Regressor/Cluster) Ab...
# About Dataset section found with tag: div
# About Dataset: The data consist of the estimation of obesity levels in people from the countries of Mexico  Peru an...
# Progress: 2387 out of 2400 datasets processed
#
# Processing: France Address Dataset (https://www.kaggle.com/datasets/taylorsamarel/france-address-dataset)
# No 'View more' button found
# Headers found: France Address Dataset France Address Dataset About Dataset Usability License Expected update freque...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 2388 out of 2400 datasets processed
#
# Processing: Random Sample of NIH Chest X-ray Dataset (https://www.kaggle.com/datasets/nih-chest-xrays/sample)
# No 'View more' button found
# Headers found: Random Sample of NIH Chest X-ray Dataset Random Sample of NIH Chest X-ray Dataset About Dataset NIH ...
# About Dataset section found with tag: div
# About Dataset: Chest X-ray exams are one of the most frequent and cost-effective medical imaging examinations avail...
# Progress: 2389 out of 2400 datasets processed
#
# Processing: Douban Movie Short Comments Dataset (https://www.kaggle.com/datasets/utmhikari/doubanmovieshortcomments)
# No 'View more' button found
# Headers found: Douban Movie Short Comments Dataset Douban Movie Short Comments Dataset About Dataset Douban Movie S...
# About Dataset section found with tag: div
# About Dataset: Douban Movie is a Chinese website that allows Internet users to share their comments and viewpoints ...
# Progress: 2390 out of 2400 datasets processed
#
# Processing: Student performance prediction (https://www.kaggle.com/datasets/rkiattisak/student-performance-in-mathematics)
# No 'View more' button found
# Headers found: Student performance prediction Student performance prediction About Dataset Usability License Expect...
# About Dataset section found with tag: div
# About Dataset: Description: This dataset contains information on the performance of high school students in mathema...
# Progress: 2391 out of 2400 datasets processed
#
# Processing: Top 100 Bestselling Book Reviews on Amazon (https://www.kaggle.com/datasets/anshtanwar/top-200-trending-books-with-reviews)
# No 'View more' button found
# Headers found: Top 100 Bestselling Book Reviews on Amazon Top 100 Bestselling Book Reviews on Amazon About Dataset ...
# About Dataset section found with tag: div
# About Dataset: This dataset offers an in-depth look into Amazon's top 100 Bestselling books along with their custom...
# Progress: 2392 out of 2400 datasets processed
#
# Processing: Big mart Sales Dataset (https://www.kaggle.com/datasets/mragpavank/big-mart-sales-dataset)
# No 'View more' button found
# Headers found: Big mart Sales Dataset Big mart Sales Dataset About Dataset Usability License Expected update freque...
# About Dataset section found with tag: div
# About Dataset: No description available
# Progress: 2393 out of 2400 datasets processed
#
# Processing: Airplane Crashes Since 1908 (https://www.kaggle.com/datasets/saurograndi/airplane-crashes-since-1908)
# No 'View more' button found
# Headers found: Airplane Crashes Since 1908 Airplane Crashes Since 1908 About Dataset Airplane Crashes and Fatalitie...
# About Dataset section found with tag: div
# About Dataset: At the time this Dataset was created in Kaggle (2016-09-09)  the original version was hosted by Open...
# Progress: 2394 out of 2400 datasets processed
#
# Processing: YouTube Sports Channels Statistics (https://www.kaggle.com/datasets/kanchana1990/youtube-sports-channels-statistics)
# No 'View more' button found
# Headers found: YouTube Sports Channels Statistics YouTube Sports Channels Statistics About Dataset Usability Licens...
# About Dataset section found with tag: div
# About Dataset: Dataset Overview:
# Progress: 2395 out of 2400 datasets processed
#
# Processing: Employee Attrition (https://www.kaggle.com/datasets/patelprashant/employee-attrition)
# No 'View more' button found
# Headers found: Employee Attrition Employee Attrition About Dataset Context Content Acknowledgements Inspiration Usa...
# About Dataset section found with tag: div
# About Dataset: The key to success in any organization is attracting and retaining top talent. I’m an HR analyst at ...
# Progress: 2396 out of 2400 datasets processed
#
# Processing: Micro Expression Dataset for Lie Detection (https://www.kaggle.com/datasets/devvratmathur/micro-expression-dataset-for-lie-detection)
# No 'View more' button found
# Headers found: Micro Expression Dataset for Lie Detection Micro Expression Dataset for Lie Detection About Dataset ...
# About Dataset section found with tag: div
# About Dataset: Lie detectionis the process of determining whether someone is being truthful or deceptive.There are ...
# Progress: 2397 out of 2400 datasets processed
#
# Processing: PPE and Heavy Machinery detection (balanced) (https://www.kaggle.com/datasets/pablogarcher24/ppe-and-heavy-machinery-detection-balanced)
# No 'View more' button found
# Headers found: PPE and Heavy Machinery detection (balanced) PPE and Heavy Machinery detection (balanced) About Data...
# About Dataset section found with tag: div
# About Dataset: This dataset has been prepared for object detection in the construction field. The following objects...
# Progress: 2398 out of 2400 datasets processed
#
# Processing: Lumbar Coordinate Colorized Dataset (https://www.kaggle.com/datasets/shuvokumarbasakbd/lumbar-coordinate-colorized-dataset)
# No 'View more' button found
# Headers found: Lumbar Coordinate Colorized Dataset Lumbar Coordinate Colorized Dataset About Dataset Usability Lice...
# About Dataset section found with tag: div
# About Dataset: Raw Data  Source  More Information ::https://www.kaggle.com/datasets/brendanartley/lumbar-coordinate...
# Progress: 2399 out of 2400 datasets processed
#
# Processing: MIMIC-III - Deep Reinforcement Learning  (https://www.kaggle.com/datasets/asjad99/mimiciii)
# No 'View more' button found
# Headers found: MIMIC-III - Deep Reinforcement Learning MIMIC-III - Deep Reinforcement Learning About Dataset Usabil...
# About Dataset section found with tag: div
# About Dataset: Digitization of healthcare data along with algorithmic breakthroughts in AI will have a major impact...
# Progress: 2400 out of 2400 datasets processed
#
# Metadata saved to kaggle_datasets_metadata.csv

# %%
from google.colab import files

# Download the CSV file
files.download("kaggle_datasets_metadata.csv")
